# %% [markdown]
# <h3>Categorigal Variables</h3>
#
# These are variables which can fit into categories!
#
# ![image.png](attachment:image.png)
#
# ML algorithms ae not typically set to work with categorical data therefore, when identified, they need to be translated ito numeric data.
#
# ![image-2.png](attachment:image-2.png)
#
# The conversion process from categorical data into numeric data is known as <strong>encoding</strong> and can be achieved via various methods using pre-built libraries.

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

data = {"names": ["Steve", "John", "Richard", "Sarah", "Randy", "Michael", "Julie"],
        "age": [20, 22, 20, 21, 24, 23, 22],
        "gender": ["Male", "Male", np.nan, "Female", np.nan, "Male", np.nan],
        "rank": [2, 1, 4, 5, 3, 7, 6]
    }
